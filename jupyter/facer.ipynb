# %%
import cv2
import shared


img_path = "./data/img/face_002.jpg"
img = shared.img.read_base64_from_file(img_path)
# img = shared.img.parser_base64_to_numpy(img)
ret = shared.http.post(
    url="http://10.133.80.51:9018/face/rec",
    data={"img": img},
)
print(ret)
# Out:
# {'code': 0, 'msg': '', 'data': [-0.051417771726846695, 0.03599446266889572, -0.05086403340101242, 0.02055496722459793, 0.05668321251869202, 0.023635780438780785, 0.06850261241197586, -0.11151918768882751, -0.009084678255021572, 0.031258467584848404, -0.0384172759950161, 0.047610048204660416, 0.07583466917276382, 0.029265394434332848, 0.04399758577346802, 0.0023406471591442823, -0.07027913630008698, -0.025111373513936996, 0.010104184970259666, 0.00819797907024622, -0.04673362523317337, 0.007073238957673311, -0.027454080060124397, -0.07965993136167526, -0.052383746951818466, 0.007565489038825035, 0.02639083005487919, -0.05632447451353073, -0.0070694731548428535, -0.023678947240114212, 0.00794806145131588, -0.06109112128615379, 0.05166756361722946, 0.02987244538962841, -0.04979824647307396, 0.02050815522670746, -0.018608665093779564, -0.02620844729244709, -0.004678922705352306, 0.10517431050539017, -0.050783488899469376, 0.05612479895353317, 0.006086492445319891, 0.0434471070766449, -0.
# ...
